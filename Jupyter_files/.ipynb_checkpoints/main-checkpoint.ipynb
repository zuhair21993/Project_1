# %% [markdown]
# # Importing Dependancies

# %%
# %matplotlib notebook 
# %matplotlib inline

import os
import csv
import random
import string
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import zipfile
from scipy.stats import linregress
import glob

# %% [markdown]
# # Reading Files & Creating DataFrames

# %%
#Air Quality Index DataFrame
aqi_df = pd.read_csv("../Output/aqi_compiled.csv")

# %%
#Gases DataFrame
co_df = pd.read_csv("../Output/co_compiled.csv")
no2_df = pd.read_csv("../Output/no2_compiled.csv")
ozone_df = pd.read_csv("../Output/ozone_compiled.csv")
so2_df = pd.read_csv("../Output/so2_compiled.csv")

# %%
#Emissions DataFrame
emission_df = pd.read_csv("../Output/emissions_compiled.csv")

# %%
nata_summary = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_allhi.csv")
nata_cancer = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_cancerrisk_by_tract_poll.csv")
nata_immune = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_immuhi_by_tract_poll.csv")
nata_kidney = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_kidnhi_by_tract_poll.csv")
nata_liver = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_liverhi_by_tract_poll.csv")
nata_neuro = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_neurhi_by_tract_poll.csv")
nata_respiratory = pd.read_csv("../Output/NATA_assessment_results_by_hazards/nata2014v2_national_resphi_by_tract_poll.csv")

# %% [markdown]
# # Analysis & Workings

# %%
good_days = aqi_df["Good Days"] + aqi_df["Moderate Days"]
unhealthy_hazardous_days = aqi_df["Unhealthy Days"] + aqi_df["Very Unhealthy Days"] + aqi_df["Hazardous Days"] 

aqi_df["Total Good & Moderate Days"] = good_days
aqi_df["Unhealthy & Hazardous Days"] = unhealthy_hazardous_days
aqi_df.head()
# Out:
#      State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama     Autauga  1980            179        122             35
# 1  Alabama     Colbert  1980            274        127             45
# 2  Alabama     Jackson  1980            366         85            110
# 3  Alabama   Jefferson  1980            343        171            109
# 4  Alabama  Lauderdale  1980            274        120             58
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                   18               4                    0
# 1                                   63              39                    0
# 2                                   92              79                    0
# 3                                   37              19                    7
# 4                                   77              19                    0
#
#    Hazardous Days  ...  90th Percentile AQI  Median AQI  Days CO  Days NO2  \
# 0               0  ...                  108          40        0         0
# 1               0  ...                  165          56        0         0
# 2               0  ...                  200          94        0         0
# 3               0  ...                  140          51      207         0
# 4               0  ...                  139          56        0         0
#
#    Days Ozone  Days SO2  Days PM2.5  Days PM10  Total Good & Moderate Days  \
# 0         122        57           0          0                         157
# 1           0       274           0          0                         172
# 2           0       366           0          0                         195
# 3         136         0           0          0                         280
# 4           0       274           0          0                         178
#
#    Unhealthy & Hazardous Days
# 0                           4
# 1                          39
# 2                          79
# 3                          26
# 4                          19
#
# [5 rows x 21 columns]

# %%
#use loc function to bring in only those rows pertaining to TriState
nj_state_aqi = aqi_df.loc[aqi_df["State"] == "New Jersey"] 
ny_state_aqi = aqi_df.loc[aqi_df["State"] == "New York"] 
ct_state_aqi = aqi_df.loc[aqi_df["State"] == "Connecticut"] 
tri_state_df = pd.concat([nj_state_aqi, ny_state_aqi, ct_state_aqi])
summarized_tri_state_df = tri_state_df[["State", "County", "Year" , "Total Good & Moderate Days", "Unhealthy & Hazardous Days", "Unhealthy for Sensitive Groups Days"]]
plot_df = summarized_tri_state_df.groupby("Year").mean()
plot_df
# Out:
#       Total Good & Moderate Days  Unhealthy & Hazardous Days  \
# Year
# 1980                  241.120000                   23.260000
# 1981                  265.333333                   13.729167
# 1982                  274.416667                   13.020833
# 1983                  270.063830                   21.404255
# 1984                  293.400000                   12.777778
# 1985                  291.521739                   14.282609
# 1986                  281.428571                    9.306122
# 1987                  284.936170                   14.000000
# 1988                  263.979592                   20.408163
# 1989                  270.235294                    8.490196
# 1990                  254.052632                    7.526316
# 1991                  264.172414                   12.810345
# 1992                  284.491525                    4.305085
# 1993                  281.661017                    6.932203
# 1994                  288.440678                    4.966102
# 1995                  289.901639                    6.819672
# 1996                  296.866667                    3.733333
# 1997                  300.396552                    7.465517
# 1998                  297.728814                    7.067797
# 1999                  303.912281                    9.280702
# 2000                  306.866667                    3.183333
# 2001                  297.050000                    6.900000
# 2002                  286.721311                   11.491803
# 2003                  297.459016                    3.737705
# 2004                  316.118644                    1.118644
# 2005                  309.237288                    3.847458
# 2006                  315.389831                    2.084746
# 2007                  320.338983                    2.677966
# 2008                  332.084746                    1.271186
# 2009                  337.250000                    0.050000
# 2010                  339.706897                    1.068966
# 2011                  331.913793                    1.206897
# 2012                  332.561404                    1.070175
# 2013                  341.622642                    0.396226
# 2014                  343.283019                    0.132075
# 2015                  339.433962                    0.264151
# 2016                  340.377358                    0.452830
# 2017                  344.727273                    0.254545
# 2018                  340.345455                    0.418182
# 2019                  221.218182                    0.000000
#
#       Unhealthy for Sensitive Groups Days
# Year
# 1980                            46.060000
# 1981                            42.645833
# 1982                            39.041667
# 1983                            39.297872
# 1984                            39.244444
# 1985                            36.782609
# 1986                            28.959184
# 1987                            28.191489
# 1988                            26.734694
# 1989                            24.392157
# 1990                            19.771930
# 1991                            23.396552
# 1992                            15.322034
# 1993                            17.864407
# 1994                            20.677966
# 1995                            15.508197
# 1996                            13.400000
# 1997                            15.017241
# 1998                            17.898305
# 1999                            17.087719
# 2000                            12.700000
# 2001                            16.883333
# 2002                            17.459016
# 2003                            11.688525
# 2004                             9.203390
# 2005                            13.847458
# 2006                             9.440678
# 2007                            14.152542
# 2008                             8.169492
# 2009                             3.116667
# 2010                             8.931034
# 2011                             5.758621
# 2012                             8.456140
# 2013                             2.905660
# 2014                             2.433962
# 2015                             5.037736
# 2016                             4.490566
# 2017                             3.018182
# 2018                             4.054545
# 2019                             1.181818

# %%
x_axis = np.arange(1980, 2020, 1)
plt.plot(x_axis, plot_df["Total Good & Moderate Days"], color='green')
plt.plot(x_axis, plot_df["Unhealthy & Hazardous Days"], color='red')
plt.plot(x_axis, plot_df["Unhealthy for Sensitive Groups Days"], color='orange')
